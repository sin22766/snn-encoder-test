# %% [markdown]
# # CHB-MIT Dataset Explore

# %%
# %matplotlib widget

# %% [markdown]
# ## Check patients list

# %%
import os

dataset_path = "./CHB-MIT"
patient_dirs = [d for d in os.listdir(dataset_path) if d.startswith("chb")]
patient_dirs
# Out:
# ['chb01',
#  'chb02',
#  'chb03',
#  'chb04',
#  'chb05',
#  'chb06',
#  'chb07',
#  'chb08',
#  'chb09',
#  'chb10',
#  'chb11',
#  'chb12',
#  'chb13',
#  'chb14',
#  'chb15',
#  'chb16',
#  'chb17',
#  'chb18',
#  'chb19',
#  'chb20',
#  'chb21',
#  'chb22',
#  'chb23',
#  'chb24']

# %% [markdown]
# ## Parse summary files

# %%
from typing import List
from utils import info

summary_info: List[info.PatientSummary] = info.parse_all_summary_files(dataset_path)
filtered_summary_info = info.filter_common_channels(summary_info)

# %%
filtered_summary_info
# Out:
# [{'patient_id': 'chb01',
#   'file_duration': 1,
#   'sampling_rate': 256,
#   'channels_list': [['FP1-F7',
#     'F7-T7',
#     'T7-P7',
#     'P7-O1',
#     'FP1-F3',
#     'F3-C3',
#     'C3-P3',
#     'P3-O1',
#     'FP2-F4',
#     'F4-C4',
#     'C4-P4',
#     'P4-O2',
#     'FP2-F8',
#     'F8-T8',
#     'T8-P8',
#     'P8-O2',
#     'FZ-CZ',
#     'CZ-PZ',
#     'P7-T7',
#     'T7-FT9',
#     'FT9-FT10',
#     'FT10-T8',
#     'T8-P8']],
#   'files': [{'name': 'chb01_01.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 11, 42, 54),
#     'end_time': datetime.datetime(2075, 3, 10, 12, 42, 54),
#     'seizures': []},
#    {'name': 'chb01_02.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 12, 42, 57),
#     'end_time': datetime.datetime(2075, 3, 10, 13, 42, 57),
#     'seizures': []},
#    {'name': 'chb01_03.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 13, 43, 4),
#     'end_time': datetime.datetime(2075, 3, 10, 14, 43, 4),
#     'seizures': [{'start_time': 2996, 'end_time': 3036}]},
#    {'name': 'chb01_04.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 14, 43, 12),
#     'end_time': datetime.datetime(2075, 3, 10, 15, 43, 12),
#     'seizures': [{'start_time': 1467, 'end_time': 1494}]},
#    {'name': 'chb01_05.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 15, 43, 19),
#     'end_time': datetime.datetime(2075, 3, 10, 16, 43, 19),
#     'seizures': []},
#    {'name': 'chb01_06.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 16, 43, 26),
#     'end_time': datetime.datetime(2075, 3, 10, 17, 43, 26),
#     'seizures': []},
#    {'name': 'chb01_07.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 17, 43, 33),
#     'end_time': datetime.datetime(2075, 3, 10, 18, 43, 33),
#     'seizures': []},
#    {'name': 'chb01_08.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 18, 43, 40),
#     'end_time': datetime.datetime(2075, 3, 10, 19, 43, 40),
#     'seizures': []},
#    {'name': 'chb01_09.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 19, 43, 56),
#     'end_time': datetime.datetime(2075, 3, 10, 20, 43, 56),
#     'seizures': []},
#    {'name': 'chb01_10.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 20, 44, 7),
#     'end_time': datetime.datetime(2075, 3, 10, 21, 44, 7),
#     'seizures': []},
#    {'name': 'chb01_11.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 21, 44, 14),
#     'end_time': datetime.datetime(2075, 3, 10, 22, 44, 14),
#     'seizures': []},
#    {'name': 'chb01_12.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 22, 44, 22),
#     'end_time': datetime.datetime(2075, 3, 10, 23, 44, 22),
#     'seizures': []},
#    {'name': 'chb01_13.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 23, 44, 29),
#     'end_time': datetime.datetime(2075, 3, 11, 0, 44, 29),
#     'seizures': []},
#    {'name': 'chb01_14.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 0, 44, 37),
#     'end_time': datetime.datetime(2075, 3, 11, 1, 44, 37),
#     'seizures': []},
#    {'name': 'chb01_15.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 1, 44, 44),
#     'end_time': datetime.datetime(2075, 3, 11, 2, 44, 44),
#     'seizures': [{'start_time': 1732, 'end_time': 1772}]},
#    {'name': 'chb01_16.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 2, 44, 51),
#     'end_time': datetime.datetime(2075, 3, 11, 3, 44, 51),
#     'seizures': [{'start_time': 1015, 'end_time': 1066}]},
#    {'name': 'chb01_17.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 3, 44, 59),
#     'end_time': datetime.datetime(2075, 3, 11, 4, 44, 59),
#     'seizures': []},
#    {'name': 'chb01_18.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 4, 45, 6),
#     'end_time': datetime.datetime(2075, 3, 11, 5, 45, 6),
#     'seizures': [{'start_time': 1720, 'end_time': 1810}]},
#    {'name': 'chb01_19.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 5, 45, 13),
#     'end_time': datetime.datetime(2075, 3, 11, 6, 45, 13),
#     'seizures': []},
#    {'name': 'chb01_20.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 6, 45, 20),
#     'end_time': datetime.datetime(2075, 3, 11, 7, 29, 43),
#     'seizures': []},
#    {'name': 'chb01_21.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 7, 33, 46),
#     'end_time': datetime.datetime(2075, 3, 11, 8, 33, 46),
#     'seizures': [{'start_time': 327, 'end_time': 420}]},
#    {'name': 'chb01_22.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 8, 33, 49),
#     'end_time': datetime.datetime(2075, 3, 11, 9, 33, 49),
#     'seizures': []},
#    {'name': 'chb01_23.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 9, 33, 58),
#     'end_time': datetime.datetime(2075, 3, 11, 10, 33, 58),
#     'seizures': []},
#    {'name': 'chb01_24.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 10, 34, 6),
#     'end_time': datetime.datetime(2075, 3, 11, 11, 34, 6),
#     'seizures': []},
#    {'name': 'chb01_25.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 11, 34, 14),
#     'end_time': datetime.datetime(2075, 3, 11, 12, 34, 14),
#     'seizures': []},
#    {'name': 'chb01_26.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 12, 34, 22),
#     'end_time': datetime.datetime(2075, 3, 11, 13, 13, 7),
#     'seizures': [{'start_time': 1862, 'end_time': 1963}]},
#    {'name': 'chb01_27.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 13, 13, 21),
#     'end_time': datetime.datetime(2075, 3, 11, 13, 23, 21),
#     'seizures': []},
#    {'name': 'chb01_29.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 13, 24, 8),
#     'end_time': datetime.datetime(2075, 3, 11, 14, 24, 8),
#     'seizures': []},
#    {'name': 'chb01_30.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 14, 24, 15),
#     'end_time': datetime.datetime(2075, 3, 11, 15, 24, 15),
#     'seizures': []},
#    {'name': 'chb01_31.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 15, 24, 24),
#     'end_time': datetime.datetime(2075, 3, 11, 16, 24, 24),
#     'seizures': []},
#    {'name': 'chb01_32.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 16, 24, 32),
#     'end_time': datetime.datetime(2075, 3, 11, 17, 24, 32),
#     'seizures': []},
#    {'name': 'chb01_33.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 17, 24, 39),
#     'end_time': datetime.datetime(2075, 3, 11, 18, 24, 39),
#     'seizures': []},
#    {'name': 'chb01_34.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 18, 24, 46),
#     'end_time': datetime.datetime(2075, 3, 11, 19, 24, 46),
#     'seizures': []},
#    {'name': 'chb01_36.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 22, 14, 43),
#     'end_time': datetime.datetime(2075, 3, 11, 23, 14, 43),
#     'seizures': []},
#    {'name': 'chb01_37.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 23, 14, 46),
#     'end_time': datetime.datetime(2075, 3, 12, 0, 14, 46),
#     'seizures': []},
#    {'name': 'chb01_38.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 0, 14, 53),
#     'end_time': datetime.datetime(2075, 3, 12, 1, 14, 53),
#     'seizures': []},
#    {'name': 'chb01_39.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 1, 15, 1),
#     'end_time': datetime.datetime(2075, 3, 12, 2, 15, 1),
#     'seizures': []},
#    {'name': 'chb01_40.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 2, 15, 8),
#     'end_time': datetime.datetime(2075, 3, 12, 3, 15, 8),
#     'seizures': []},
#    {'name': 'chb01_41.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 3, 15, 15),
#     'end_time': datetime.datetime(2075, 3, 12, 4, 15, 15),
#     'seizures': []},
#    {'name': 'chb01_42.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 4, 15, 22),
#     'end_time': datetime.datetime(2075, 3, 12, 5, 15, 22),
#     'seizures': []},
#    {'name': 'chb01_43.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 5, 15, 29),
#     'end_time': datetime.datetime(2075, 3, 12, 6, 15, 29),
#     'seizures': []},
#    {'name': 'chb01_46.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 8, 15, 51),
#     'end_time': datetime.datetime(2075, 3, 12, 9, 15, 51),
#     'seizures': []}]},
#  {'patient_id': 'chb02',
#   'file_duration': 1,
#   'sampling_rate': 256,
#   'channels_list': [['FP1-F7',
#     'F7-T7',
#     'T7-P7',
#     'P7-O1',
#     'FP1-F3',
#     'F3-C3',
#     'C3-P3',
#     'P3-O1',
#     'FP2-F4',
#     'F4-C4',
#     'C4-P4',
#     'P4-O2',
#     'FP2-F8',
#     'F8-T8',
#     'T8-P8',
#     'P8-O2',
#     'FZ-CZ',
#     'CZ-PZ',
#     'P7-T7',
#     'T7-FT9',
#     'FT9-FT10',
#     'FT10-T8',
#     'T8-P8']],
#   'files': [{'name': 'chb02_01.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 15, 29, 39),
#     'end_time': datetime.datetime(2075, 3, 10, 16, 29, 39),
#     'seizures': []},
#    {'name': 'chb02_02.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 17, 29, 49),
#     'end_time': datetime.datetime(2075, 3, 10, 18, 29, 49),
#     'seizures': []},
#    {'name': 'chb02_03.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 18, 29, 56),
#     'end_time': datetime.datetime(2075, 3, 10, 19, 29, 56),
#     'seizures': []},
#    {'name': 'chb02_04.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 19, 30, 3),
#     'end_time': datetime.datetime(2075, 3, 10, 20, 30, 3),
#     'seizures': []},
#    {'name': 'chb02_05.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 20, 30, 10),
#     'end_time': datetime.datetime(2075, 3, 10, 21, 30, 10),
#     'seizures': []},
#    {'name': 'chb02_06.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 21, 30, 18),
#     'end_time': datetime.datetime(2075, 3, 10, 22, 30, 18),
#     'seizures': []},
#    {'name': 'chb02_07.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 22, 30, 25),
#     'end_time': datetime.datetime(2075, 3, 10, 23, 30, 25),
#     'seizures': []},
#    {'name': 'chb02_08.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 23, 30, 33),
#     'end_time': datetime.datetime(2075, 3, 11, 0, 30, 33),
#     'seizures': []},
#    {'name': 'chb02_09.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 0, 30, 40),
#     'end_time': datetime.datetime(2075, 3, 11, 1, 30, 40),
#     'seizures': []},
#    {'name': 'chb02_10.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 1, 30, 47),
#     'end_time': datetime.datetime(2075, 3, 11, 2, 30, 47),
#     'seizures': []},
#    {'name': 'chb02_11.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 2, 30, 55),
#     'end_time': datetime.datetime(2075, 3, 11, 3, 30, 55),
#     'seizures': []},
#    {'name': 'chb02_12.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 3, 31, 2),
#     'end_time': datetime.datetime(2075, 3, 11, 4, 31, 2),
#     'seizures': []},
#    {'name': 'chb02_13.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 4, 31, 9),
#     'end_time': datetime.datetime(2075, 3, 11, 5, 31, 9),
#     'seizures': []},
#    {'name': 'chb02_14.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 5, 31, 17),
#     'end_time': datetime.datetime(2075, 3, 11, 6, 31, 17),
#     'seizures': []},
#    {'name': 'chb02_15.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 8, 31, 38),
#     'end_time': datetime.datetime(2075, 3, 11, 9, 31, 38),
#     'seizures': []},
#    {'name': 'chb02_16.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 9, 31, 46),
#     'end_time': datetime.datetime(2075, 3, 11, 9, 47, 45),
#     'seizures': [{'start_time': 130, 'end_time': 212}]},
#    {'name': 'chb02_16+.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 10, 50, 23),
#     'end_time': datetime.datetime(2075, 3, 11, 11, 50, 23),
#     'seizures': [{'start_time': 2972, 'end_time': 3053}]},
#    {'name': 'chb02_17.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 11, 50, 31),
#     'end_time': datetime.datetime(2075, 3, 11, 12, 50, 31),
#     'seizures': []},
#    {'name': 'chb02_18.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 12, 50, 38),
#     'end_time': datetime.datetime(2075, 3, 11, 13, 50, 38),
#     'seizures': []},
#    {'name': 'chb02_19.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 13, 50, 45),
#     'end_time': datetime.datetime(2075, 3, 11, 14, 50, 45),
#     'seizures': [{'start_time': 3369, 'end_time': 3378}]},
#    {'name': 'chb02_20.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 14, 50, 53),
#     'end_time': datetime.datetime(2075, 3, 11, 15, 50, 53),
#     'seizures': []},
#    {'name': 'chb02_21.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 15, 51),
#     'end_time': datetime.datetime(2075, 3, 11, 16, 51),
#     'seizures': []},
#    {'name': 'chb02_22.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 16, 51, 8),
#     'end_time': datetime.datetime(2075, 3, 11, 17, 51, 8),
#     'seizures': []},
#    {'name': 'chb02_23.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 19, 2, 27),
#     'end_time': datetime.datetime(2075, 3, 11, 20, 2, 27),
#     'seizures': []},
#    {'name': 'chb02_24.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 20, 2, 40),
#     'end_time': datetime.datetime(2075, 3, 11, 21, 2, 40),
#     'seizures': []},
#    {'name': 'chb02_25.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 21, 2, 48),
#     'end_time': datetime.datetime(2075, 3, 11, 22, 2, 48),
#     'seizures': []},
#    {'name': 'chb02_26.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 22, 2, 55),
#     'end_time': datetime.datetime(2075, 3, 11, 23, 2, 55),
#     'seizures': []},
#    {'name': 'chb02_27.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 23, 3, 3),
#     'end_time': datetime.datetime(2075, 3, 12, 0, 3, 3),
#     'seizures': []},
#    {'name': 'chb02_28.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 0, 3, 10),
#     'end_time': datetime.datetime(2075, 3, 12, 1, 3, 10),
#     'seizures': []},
#    {'name': 'chb02_29.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 1, 3, 18),
#     'end_time': datetime.datetime(2075, 3, 12, 2, 3, 18),
#     'seizures': []},
#    {'name': 'chb02_30.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 2, 3, 25),
#     'end_time': datetime.datetime(2075, 3, 12, 3, 3, 25),
#     'seizures': []},
#    {'name': 'chb02_31.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 3, 3, 33),
#     'end_time': datetime.datetime(2075, 3, 12, 4, 3, 33),
#     'seizures': []},
#    {'name': 'chb02_32.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 4, 3, 40),
#     'end_time': datetime.datetime(2075, 3, 12, 5, 3, 40),
#     'seizures': []},
#    {'name': 'chb02_33.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 5, 3, 47),
#     'end_time': datetime.datetime(2075, 3, 12, 6, 3, 47),
#     'seizures': []},
#    {'name': 'chb02_34.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 6, 3, 55),
#     'end_time': datetime.datetime(2075, 3, 12, 7, 3, 55),
#     'seizures': []},
#    {'name': 'chb02_35.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 7, 4, 2),
#     'end_time': datetime.datetime(2075, 3, 12, 8, 4, 2),
#     'seizures': []}]},
#  {'patient_id': 'chb03',
#   'file_duration': 1,
#   'sampling_rate': 256,
#   'channels_list': [['FP1-F7',
#     'F7-T7',
#     'T7-P7',
#     'P7-O1',
#     'FP1-F3',
#     'F3-C3',
#     'C3-P3',
#     'P3-O1',
#     'FP2-F4',
#     'F4-C4',
#     'C4-P4',
#     'P4-O2',
#     'FP2-F8',
#     'F8-T8',
#     'T8-P8',
#     'P8-O2',
#     'FZ-CZ',
#     'CZ-PZ',
#     'P7-T7',
#     'T7-FT9',
#     'FT9-FT10',
#     'FT10-T8',
#     'T8-P8']],
#   'files': [{'name': 'chb03_01.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 13, 23, 36),
#     'end_time': datetime.datetime(2075, 3, 10, 14, 23, 36),
#     'seizures': [{'start_time': 362, 'end_time': 414}]},
#    {'name': 'chb03_02.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 14, 23, 39),
#     'end_time': datetime.datetime(2075, 3, 10, 15, 23, 39),
#     'seizures': [{'start_time': 731, 'end_time': 796}]},
#    {'name': 'chb03_03.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 15, 23, 47),
#     'end_time': datetime.datetime(2075, 3, 10, 16, 23, 47),
#     'seizures': [{'start_time': 432, 'end_time': 501}]},
#    {'name': 'chb03_04.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 16, 23, 54),
#     'end_time': datetime.datetime(2075, 3, 10, 17, 23, 54),
#     'seizures': [{'start_time': 2162, 'end_time': 2214}]},
#    {'name': 'chb03_05.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 17, 24, 1),
#     'end_time': datetime.datetime(2075, 3, 10, 18, 24, 1),
#     'seizures': []},
#    {'name': 'chb03_06.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 18, 24, 8),
#     'end_time': datetime.datetime(2075, 3, 10, 19, 24, 8),
#     'seizures': []},
#    {'name': 'chb03_07.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 19, 24, 15),
#     'end_time': datetime.datetime(2075, 3, 10, 20, 24, 15),
#     'seizures': []},
#    {'name': 'chb03_08.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 20, 24, 22),
#     'end_time': datetime.datetime(2075, 3, 10, 21, 24, 22),
#     'seizures': []},
#    {'name': 'chb03_09.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 21, 24, 30),
#     'end_time': datetime.datetime(2075, 3, 10, 22, 24, 30),
#     'seizures': []},
#    {'name': 'chb03_10.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 22, 24, 37),
#     'end_time': datetime.datetime(2075, 3, 10, 23, 24, 37),
#     'seizures': []},
#    {'name': 'chb03_11.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 23, 24, 44),
#     'end_time': datetime.datetime(2075, 3, 11, 0, 24, 44),
#     'seizures': []},
#    {'name': 'chb03_12.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 0, 24, 51),
#     'end_time': datetime.datetime(2075, 3, 11, 1, 24, 51),
#     'seizures': []},
#    {'name': 'chb03_13.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 1, 24, 59),
#     'end_time': datetime.datetime(2075, 3, 11, 2, 24, 59),
#     'seizures': []},
#    {'name': 'chb03_14.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 2, 25, 6),
#     'end_time': datetime.datetime(2075, 3, 11, 3, 25, 6),
#     'seizures': []},
#    {'name': 'chb03_15.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 3, 25, 13),
#     'end_time': datetime.datetime(2075, 3, 11, 4, 25, 13),
#     'seizures': []},
#    {'name': 'chb03_16.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 4, 25, 20),
#     'end_time': datetime.datetime(2075, 3, 11, 5, 25, 20),
#     'seizures': []},
#    {'name': 'chb03_17.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 5, 25, 27),
#     'end_time': datetime.datetime(2075, 3, 11, 6, 25, 27),
#     'seizures': []},
#    {'name': 'chb03_18.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 6, 25, 34),
#     'end_time': datetime.datetime(2075, 3, 11, 7, 25, 34),
#     'seizures': []},
#    {'name': 'chb03_19.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 7, 25, 42),
#     'end_time': datetime.datetime(2075, 3, 11, 8, 25, 42),
#     'seizures': []},
#    {'name': 'chb03_20.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 8, 25, 51),
#     'end_time': datetime.datetime(2075, 3, 11, 9, 25, 57),
#     'seizures': []},
#    {'name': 'chb03_21.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 12, 38, 31),
#     'end_time': datetime.datetime(2075, 3, 11, 13, 38, 31),
#     'seizures': []},
#    {'name': 'chb03_22.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 13, 38, 38),
#     'end_time': datetime.datetime(2075, 3, 11, 14, 38, 38),
#     'seizures': []},
#    {'name': 'chb03_23.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 14, 38, 45),
#     'end_time': datetime.datetime(2075, 3, 11, 15, 38, 45),
#     'seizures': []},
#    {'name': 'chb03_24.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 16, 39, 5),
#     'end_time': datetime.datetime(2075, 3, 11, 17, 39, 5),
#     'seizures': []},
#    {'name': 'chb03_25.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 15, 38, 57),
#     'end_time': datetime.datetime(2075, 3, 12, 16, 38, 57),
#     'seizures': []},
#    {'name': 'chb03_26.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 17, 39, 12),
#     'end_time': datetime.datetime(2075, 3, 12, 18, 39, 12),
#     'seizures': []},
#    {'name': 'chb03_27.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 18, 39, 20),
#     'end_time': datetime.datetime(2075, 3, 12, 19, 39, 20),
#     'seizures': []},
#    {'name': 'chb03_28.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 19, 39, 27),
#     'end_time': datetime.datetime(2075, 3, 12, 20, 39, 27),
#     'seizures': []},
#    {'name': 'chb03_29.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 20, 39, 34),
#     'end_time': datetime.datetime(2075, 3, 12, 21, 39, 34),
#     'seizures': []},
#    {'name': 'chb03_30.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 21, 39, 42),
#     'end_time': datetime.datetime(2075, 3, 12, 22, 39, 42),
#     'seizures': []},
#    {'name': 'chb03_31.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 13, 16, 50, 17),
#     'end_time': datetime.datetime(2075, 3, 13, 17, 50, 17),
#     'seizures': []},
#    {'name': 'chb03_32.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 13, 17, 50, 25),
#     'end_time': datetime.datetime(2075, 3, 13, 18, 50, 25),
#     'seizures': []},
#    {'name': 'chb03_33.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 13, 18, 50, 32),
#     'end_time': datetime.datetime(2075, 3, 13, 19, 50, 32),
#     'seizures': []},
#    {'name': 'chb03_34.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 14, 1, 51, 23),
#     'end_time': datetime.datetime(2075, 3, 14, 2, 51, 23),
#     'seizures': [{'start_time': 1982, 'end_time': 2029}]},
#    {'name': 'chb03_35.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 14, 2, 51, 30),
#     'end_time': datetime.datetime(2075, 3, 14, 3, 51, 30),
#     'seizures': [{'start_time': 2592, 'end_time': 2656}]},
#    {'name': 'chb03_36.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 14, 4, 51, 45),
#     'end_time': datetime.datetime(2075, 3, 14, 5, 51, 45),
#     'seizures': [{'start_time': 1725, 'end_time': 1778}]},
#    {'name': 'chb03_37.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 14, 21, 15, 28),
#     'end_time': datetime.datetime(2075, 3, 14, 22, 15, 28),
#     'seizures': []},
#    {'name': 'chb03_38.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 14, 22, 15, 35),
#     'end_time': datetime.datetime(2075, 3, 14, 23, 15, 35),
#     'seizures': []}]},
#  {'patient_id': 'chb04',
#   'file_duration': 4,
#   'sampling_rate': 256,
#   'channels_list': [['FP1-F7',
#     'F7-T7',
#     'T7-P7',
#     'P7-O1',
#     'FP1-F3',
#     'F3-C3',
#     'C3-P3',
#     'P3-O1',
#     'FP2-F4',
#     'F4-C4',
#     'C4-P4',
#     'P4-O2',
#     'FP2-F8',
#     'F8-T8',
#     'T8-P8',
#     'P8-O2',
#     'FZ-CZ',
#     'CZ-PZ',
#     'P7-T7',
#     'T7-FT9',
#     'FT9-FT10',
#     'FT10-T8',
#     'T8-P8'],
#    ['FP1-F7',
#     'F7-T7',
#     'T7-P7',
#     'P7-O1',
#     'FP1-F3',
#     'F3-C3',
#     'C3-P3',
#     'P3-O1',
#     'FP2-F4',
#     'F4-C4',
#     'C4-P4',
#     'P4-O2',
#     'FP2-F8',
#     'F8-T8',
#     'T8-P8',
#     'P8-O2',
#     'FZ-CZ',
#     'CZ-PZ',
#     'P7-T7',
#     'T7-FT9',
#     'FT9-FT10',
#     'FT10-T8',
#     'T8-P8',
#     'ECG']],
#   'files': [{'name': 'chb04_01.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 18, 1, 25),
#     'end_time': datetime.datetime(2075, 3, 10, 22, 1, 23),
#     'seizures': []},
#    {'name': 'chb04_02.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 22, 2, 15),
#     'end_time': datetime.datetime(2075, 3, 11, 2, 2, 15),
#     'seizures': []},
#    {'name': 'chb04_03.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 2, 2, 23),
#     'end_time': datetime.datetime(2075, 3, 11, 6, 2, 23),
#     'seizures': []},
#    {'name': 'chb04_04.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 6, 2, 30),
#     'end_time': datetime.datetime(2075, 3, 11, 10, 2, 30),
#     'seizures': []},
#    {'name': 'chb04_05.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 10, 2, 37),
#     'end_time': datetime.datetime(2075, 3, 11, 12, 41, 33),
#     'seizures': [{'start_time': 7804, 'end_time': 7853}]},
#    {'name': 'chb04_06.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 12, 45, 50),
#     'end_time': datetime.datetime(2075, 3, 11, 16, 45, 50),
#     'seizures': []},
#    {'name': 'chb04_07.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 11, 16, 45, 53),
#     'end_time': datetime.datetime(2075, 3, 11, 18, 50, 49),
#     'seizures': []},
#    {'name': 'chb04_08.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 11, 18, 53, 30),
#     'end_time': datetime.datetime(2075, 3, 11, 22, 53, 30),
#     'seizures': [{'start_time': 6446, 'end_time': 6557}]},
#    {'name': 'chb04_09.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 11, 22, 53, 33),
#     'end_time': datetime.datetime(2075, 3, 12, 2, 53, 33),
#     'seizures': []},
#    {'name': 'chb04_10.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 12, 2, 53, 41),
#     'end_time': datetime.datetime(2075, 3, 12, 6, 53, 41),
#     'seizures': []},
#    {'name': 'chb04_11.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 12, 6, 53, 48),
#     'end_time': datetime.datetime(2075, 3, 12, 8, 14, 20),
#     'seizures': []},
#    {'name': 'chb04_12.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 12, 8, 16, 27),
#     'end_time': datetime.datetime(2075, 3, 12, 12, 16, 47),
#     'seizures': []},
#    {'name': 'chb04_13.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 12, 12, 17, 31),
#     'end_time': datetime.datetime(2075, 3, 12, 16, 17, 29),
#     'seizures': []},
#    {'name': 'chb04_14.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 12, 16, 18, 2),
#     'end_time': datetime.datetime(2075, 3, 12, 20, 18, 20),
#     'seizures': []},
#    {'name': 'chb04_15.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 12, 20, 19, 43),
#     'end_time': datetime.datetime(2075, 3, 13, 0, 19, 43),
#     'seizures': []},
#    {'name': 'chb04_16.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 13, 0, 19, 51),
#     'end_time': datetime.datetime(2075, 3, 13, 4, 19, 51),
#     'seizures': []},
#    {'name': 'chb04_17.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 13, 4, 19, 59),
#     'end_time': datetime.datetime(2075, 3, 13, 8, 8, 51),
#     'seizures': []},
#    {'name': 'chb04_18.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 13, 8, 11, 11),
#     'end_time': datetime.datetime(2075, 3, 13, 12, 11, 36),
#     'seizures': []},
#    {'name': 'chb04_19.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 13, 12, 41, 24),
#     'end_time': datetime.datetime(2075, 3, 13, 16, 41, 24),
#     'seizures': []},
#    {'name': 'chb04_21.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 13, 20, 41, 40),
#     'end_time': datetime.datetime(2075, 3, 14, 0, 41, 40),
#     'seizures': []},
#    {'name': 'chb04_22.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 14, 0, 41, 48),
#     'end_time': datetime.datetime(2075, 3, 14, 4, 41, 48),
#     'seizures': []},
#    {'name': 'chb04_23.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 14, 4, 41, 55),
#     'end_time': datetime.datetime(2075, 3, 14, 7, 39, 59),
#     'seizures': []},
#    {'name': 'chb04_24.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 14, 7, 41, 42),
#     'end_time': datetime.datetime(2075, 3, 14, 11, 41, 48),
#     'seizures': []},
#    {'name': 'chb04_25.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 14, 11, 46, 2),
#     'end_time': datetime.datetime(2075, 3, 14, 15, 46, 2),
#     'seizures': []},
#    {'name': 'chb04_26.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 14, 15, 46, 10),
#     'end_time': datetime.datetime(2075, 3, 14, 19, 46, 10),
#     'seizures': []},
#    {'name': 'chb04_27.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 14, 19, 46, 17),
#     'end_time': datetime.datetime(2075, 3, 14, 23, 46, 44),
#     'seizures': []},
#    {'name': 'chb04_28.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 15, 0, 4, 47),
#     'end_time': datetime.datetime(2075, 3, 15, 4, 5, 10),
#     'seizures': [{'start_time': 1679, 'end_time': 1781},
#      {'start_time': 3782, 'end_time': 3898}]},
#    {'name': 'chb04_29.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 15, 4, 6, 56),
#     'end_time': datetime.datetime(2075, 3, 15, 8, 6, 59),
#     'seizures': []},
#    {'name': 'chb04_30.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 15, 8, 7, 45),
#     'end_time': datetime.datetime(2075, 3, 15, 12, 7, 45),
#     'seizures': []},
#    {'name': 'chb04_31.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 15, 12, 7, 53),
#     'end_time': datetime.datetime(2075, 3, 15, 16, 7, 53),
#     'seizures': []},
#    {'name': 'chb04_32.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 15, 16, 8),
#     'end_time': datetime.datetime(2075, 3, 15, 20, 8),
#     'seizures': []},
#    {'name': 'chb04_33.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 15, 20, 8, 8),
#     'end_time': datetime.datetime(2075, 3, 16, 0, 8, 8),
#     'seizures': []},
#    {'name': 'chb04_34.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 16, 0, 8, 16),
#     'end_time': datetime.datetime(2075, 3, 16, 4, 8, 16),
#     'seizures': []},
#    {'name': 'chb04_35.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 16, 4, 8, 24),
#     'end_time': datetime.datetime(2075, 3, 16, 8, 8, 24),
#     'seizures': []},
#    {'name': 'chb04_36.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 16, 8, 8, 31),
#     'end_time': datetime.datetime(2075, 3, 16, 12, 8, 31),
#     'seizures': []},
#    {'name': 'chb04_37.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 16, 12, 8, 39),
#     'end_time': datetime.datetime(2075, 3, 16, 13, 42, 12),
#     'seizures': []},
#    {'name': 'chb04_38.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 16, 14, 37, 59),
#     'end_time': datetime.datetime(2075, 3, 16, 18, 37, 59),
#     'seizures': []},
#    {'name': 'chb04_39.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 16, 18, 38, 2),
#     'end_time': datetime.datetime(2075, 3, 16, 22, 38, 2),
#     'seizures': []},
#    {'name': 'chb04_40.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 16, 22, 38, 10),
#     'end_time': datetime.datetime(2075, 3, 17, 2, 38, 10),
#     'seizures': []},
#    {'name': 'chb04_41.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 17, 2, 38, 18),
#     'end_time': datetime.datetime(2075, 3, 17, 6, 38, 18),
#     'seizures': []},
#    {'name': 'chb04_42.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 17, 6, 38, 25),
#     'end_time': datetime.datetime(2075, 3, 17, 8, 15, 28),
#     'seizures': []},
#    {'name': 'chb04_43.edf',
#     'channels_set_idx': 1,
#     'start_time': datetime.datetime(2075, 3, 17, 8, 17, 50),
#     'end_time': datetime.datetime(2075, 3, 17, 12, 17, 50),
#     'seizures': []}]},
#  {'patient_id': 'chb05',
#   'file_duration': 1,
#   'sampling_rate': 256,
#   'channels_list': [['FP1-F7',
#     'F7-T7',
#     'T7-P7',
#     'P7-O1',
#     'FP1-F3',
#     'F3-C3',
#     'C3-P3',
#     'P3-O1',
#     'FP2-F4',
#     'F4-C4',
#     'C4-P4',
#     'P4-O2',
#     'FP2-F8',
#     'F8-T8',
#     'T8-P8',
#     'P8-O2',
#     'FZ-CZ',
#     'CZ-PZ',
#     'P7-T7',
#     'T7-FT9',
#     'FT9-FT10',
#     'FT10-T8',
#     'T8-P8']],
#   'files': [{'name': 'chb05_01.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 17, 20, 5),
#     'end_time': datetime.datetime(2075, 3, 10, 18, 20, 15),
#     'seizures': []},
#    {'name': 'chb05_02.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 18, 20, 57),
#     'end_time': datetime.datetime(2075, 3, 10, 19, 20, 57),
#     'seizures': []},
#    {'name': 'chb05_03.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 19, 21, 4),
#     'end_time': datetime.datetime(2075, 3, 10, 20, 21, 4),
#     'seizures': []},
#    {'name': 'chb05_04.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 20, 21, 11),
#     'end_time': datetime.datetime(2075, 3, 10, 21, 21, 11),
#     'seizures': []},
#    {'name': 'chb05_05.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 21, 21, 19),
#     'end_time': datetime.datetime(2075, 3, 10, 22, 21, 19),
#     'seizures': []},
#    {'name': 'chb05_06.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 22, 21, 25),
#     'end_time': datetime.datetime(2075, 3, 10, 23, 21, 25),
#     'seizures': [{'start_time': 417, 'end_time': 532}]},
#    {'name': 'chb05_07.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 23, 21, 32),
#     'end_time': datetime.datetime(2075, 3, 11, 0, 21, 32),
#     'seizures': []},
#    {'name': 'chb05_08.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 0, 21, 39),
#     'end_time': datetime.datetime(2075, 3, 11, 1, 21, 39),
#     'seizures': []},
#    {'name': 'chb05_09.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 1, 21, 46),
#     'end_time': datetime.datetime(2075, 3, 11, 2, 21, 46),
#     'seizures': []},
#    {'name': 'chb05_10.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 2, 21, 53),
#     'end_time': datetime.datetime(2075, 3, 11, 3, 21, 53),
#     'seizures': []},
#    {'name': 'chb05_11.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 3, 22, 1),
#     'end_time': datetime.datetime(2075, 3, 11, 4, 22, 1),
#     'seizures': []},
#    {'name': 'chb05_12.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 4, 22, 8),
#     'end_time': datetime.datetime(2075, 3, 11, 5, 22, 8),
#     'seizures': []},
#    {'name': 'chb05_13.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 5, 22, 15),
#     'end_time': datetime.datetime(2075, 3, 11, 6, 22, 15),
#     'seizures': [{'start_time': 1086, 'end_time': 1196}]},
#    {'name': 'chb05_14.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 6, 22, 21),
#     'end_time': datetime.datetime(2075, 3, 11, 7, 22, 21),
#     'seizures': []},
#    {'name': 'chb05_15.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 7, 22, 28),
#     'end_time': datetime.datetime(2075, 3, 11, 8, 22, 28),
#     'seizures': []},
#    {'name': 'chb05_16.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 8, 22, 35),
#     'end_time': datetime.datetime(2075, 3, 11, 9, 22, 35),
#     'seizures': [{'start_time': 2317, 'end_time': 2413}]},
#    {'name': 'chb05_17.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 9, 22, 42),
#     'end_time': datetime.datetime(2075, 3, 11, 10, 22, 42),
#     'seizures': [{'start_time': 2451, 'end_time': 2571}]},
#    {'name': 'chb05_18.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 10, 22, 50),
#     'end_time': datetime.datetime(2075, 3, 11, 11, 22, 50),
#     'seizures': []},
#    {'name': 'chb05_19.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 11, 22, 57),
#     'end_time': datetime.datetime(2075, 3, 11, 12, 22, 57),
#     'seizures': []},
#    {'name': 'chb05_20.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 12, 23, 4),
#     'end_time': datetime.datetime(2075, 3, 11, 13, 23, 4),
#     'seizures': []},
#    {'name': 'chb05_21.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 13, 23, 11),
#     'end_time': datetime.datetime(2075, 3, 11, 14, 23, 11),
#     'seizures': []},
#    {'name': 'chb05_22.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 14, 23, 17),
#     'end_time': datetime.datetime(2075, 3, 11, 15, 23, 17),
#     'seizures': [{'start_time': 2348, 'end_time': 2465}]},
#    {'name': 'chb05_23.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 15, 23, 24),
#     'end_time': datetime.datetime(2075, 3, 11, 16, 23, 24),
#     'seizures': []},
#    {'name': 'chb05_24.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 16, 23, 31),
#     'end_time': datetime.datetime(2075, 3, 11, 17, 23, 31),
#     'seizures': []},
#    {'name': 'chb05_25.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 17, 23, 38),
#     'end_time': datetime.datetime(2075, 3, 11, 18, 23, 38),
#     'seizures': []},
#    {'name': 'chb05_26.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 18, 23, 46),
#     'end_time': datetime.datetime(2075, 3, 11, 19, 23, 46),
#     'seizures': []},
#    {'name': 'chb05_27.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 19, 23, 53),
#     'end_time': datetime.datetime(2075, 3, 11, 20, 23, 53),
#     'seizures': []},
#    {'name': 'chb05_28.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 20, 24),
#     'end_time': datetime.datetime(2075, 3, 11, 21, 24),
#     'seizures': []},
#    {'name': 'chb05_29.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 21, 24, 7),
#     'end_time': datetime.datetime(2075, 3, 11, 22, 24, 7),
#     'seizures': []},
#    {'name': 'chb05_30.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 22, 24, 14),
#     'end_time': datetime.datetime(2075, 3, 11, 23, 24, 14),
#     'seizures': []},
#    {'name': 'chb05_31.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 23, 24, 21),
#     'end_time': datetime.datetime(2075, 3, 12, 0, 24, 21),
#     'seizures': []},
#    {'name': 'chb05_32.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 0, 24, 28),
#     'end_time': datetime.datetime(2075, 3, 12, 1, 24, 28),
#     'seizures': []},
#    {'name': 'chb05_33.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 1, 24, 35),
#     'end_time': datetime.datetime(2075, 3, 12, 2, 24, 35),
#     'seizures': []},
#    {'name': 'chb05_34.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 2, 24, 42),
#     'end_time': datetime.datetime(2075, 3, 12, 3, 24, 42),
#     'seizures': []},
#    {'name': 'chb05_35.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 3, 24, 49),
#     'end_time': datetime.datetime(2075, 3, 12, 4, 24, 49),
#     'seizures': []},
#    {'name': 'chb05_36.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 4, 24, 56),
#     'end_time': datetime.datetime(2075, 3, 12, 5, 24, 56),
#     'seizures': []},
#    {'name': 'chb05_37.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 5, 25, 3),
#     'end_time': datetime.datetime(2075, 3, 12, 6, 25, 3),
#     'seizures': []},
#    {'name': 'chb05_38.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 6, 25, 10),
#     'end_time': datetime.datetime(2075, 3, 12, 7, 25, 10),
#     'seizures': []},
#    {'name': 'chb05_39.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 7, 25, 17),
#     'end_time': datetime.datetime(2075, 3, 12, 8, 25, 17),
#     'seizures': []}]},
#  {'patient_id': 'chb06',
#   'file_duration': 4,
#   'sampling_rate': 256,
#   'channels_list': [['FP1-F7',
#     'F7-T7',
#     'T7-P7',
#     'P7-O1',
#     'FP1-F3',
#     'F3-C3',
#     'C3-P3',
#     'P3-O1',
#     'FP2-F4',
#     'F4-C4',
#     'C4-P4',
#     'P4-O2',
#     'FP2-F8',
#     'F8-T8',
#     'T8-P8',
#     'P8-O2',
#     'FZ-CZ',
#     'CZ-PZ',
#     'P7-T7',
#     'T7-FT9',
#     'FT9-FT10',
#     'FT10-T8',
#     'T8-P8']],
#   'files': [{'name': 'chb06_01.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 19, 8, 32),
#     'end_time': datetime.datetime(2075, 3, 10, 23, 8, 59),
#     'seizures': [{'start_time': 1724, 'end_time': 1738},
#      {'start_time': 7461, 'end_time': 7476},
#      {'start_time': 13525, 'end_time': 13540}]},
#    {'name': 'chb06_02.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 23, 9, 34),
#     'end_time': datetime.datetime(2075, 3, 11, 3, 9, 34),
#     'seizures': []},
#    {'name': 'chb06_03.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 3, 9, 42),
#     'end_time': datetime.datetime(2075, 3, 11, 7, 9, 42),
#     'seizures': []},
#    {'name': 'chb06_04.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 7, 9, 51),
#     'end_time': datetime.datetime(2075, 3, 11, 10, 50, 52),
#     'seizures': [{'start_time': 327, 'end_time': 347},
#      {'start_time': 6211, 'end_time': 6231}]},
#    {'name': 'chb06_05.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 10, 51, 20),
#     'end_time': datetime.datetime(2075, 3, 11, 14, 51, 20),
#     'seizures': []},
#    {'name': 'chb06_06.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 14, 51, 23),
#     'end_time': datetime.datetime(2075, 3, 11, 18, 51, 23),
#     'seizures': []},
#    {'name': 'chb06_07.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 18, 51, 31),
#     'end_time': datetime.datetime(2075, 3, 11, 22, 51, 31),
#     'seizures': []},
#    {'name': 'chb06_08.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 22, 51, 39),
#     'end_time': datetime.datetime(2075, 3, 12, 2, 51, 39),
#     'seizures': []},
#    {'name': 'chb06_09.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 2, 51, 47),
#     'end_time': datetime.datetime(2075, 3, 12, 6, 51, 47),
#     'seizures': [{'start_time': 12500, 'end_time': 12516}]},
#    {'name': 'chb06_10.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 6, 51, 54),
#     'end_time': datetime.datetime(2075, 3, 12, 10, 51, 54),
#     'seizures': [{'start_time': 10833, 'end_time': 10845}]},
#    {'name': 'chb06_12.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 14, 52, 10),
#     'end_time': datetime.datetime(2075, 3, 12, 18, 52, 10),
#     'seizures': []},
#    {'name': 'chb06_13.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 18, 52, 20),
#     'end_time': datetime.datetime(2075, 3, 12, 22, 52, 20),
#     'seizures': [{'start_time': 506, 'end_time': 519}]},
#    {'name': 'chb06_14.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 22, 52, 35),
#     'end_time': datetime.datetime(2075, 3, 13, 2, 52, 35),
#     'seizures': []},
#    {'name': 'chb06_15.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 13, 2, 52, 43),
#     'end_time': datetime.datetime(2075, 3, 13, 6, 52, 43),
#     'seizures': []},
#    {'name': 'chb06_16.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 13, 6, 52, 51),
#     'end_time': datetime.datetime(2075, 3, 13, 7, 43, 21),
#     'seizures': []},
#    {'name': 'chb06_17.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 13, 7, 45, 51),
#     'end_time': datetime.datetime(2075, 3, 13, 11, 45, 51),
#     'seizures': []},
#    {'name': 'chb06_18.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 13, 11, 45, 55),
#     'end_time': datetime.datetime(2075, 3, 13, 13, 58, 3),
#     'seizures': [{'start_time': 7799, 'end_time': 7811}]},
#    {'name': 'chb06_24.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 14, 8, 23, 24),
#     'end_time': datetime.datetime(2075, 3, 14, 12, 23, 24),
#     'seizures': [{'start_time': 9387, 'end_time': 9403}]}]},
#  {'patient_id': 'chb07',
#   'file_duration': 4,
#   'sampling_rate': 256,
#   'channels_list': [['FP1-F7',
#     'F7-T7',
#     'T7-P7',
#     'P7-O1',
#     'FP1-F3',
#     'F3-C3',
#     'C3-P3',
#     'P3-O1',
#     'FP2-F4',
#     'F4-C4',
#     'C4-P4',
#     'P4-O2',
#     'FP2-F8',
#     'F8-T8',
#     'T8-P8',
#     'P8-O2',
#     'FZ-CZ',
#     'CZ-PZ',
#     'P7-T7',
#     'T7-FT9',
#     'FT9-FT10',
#     'FT10-T8',
#     'T8-P8']],
#   'files': [{'name': 'chb07_01.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 16, 58, 28),
#     'end_time': datetime.datetime(2075, 3, 10, 20, 58, 39),
#     'seizures': []},
#    {'name': 'chb07_02.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 21, 0, 13),
#     'end_time': datetime.datetime(2075, 3, 11, 1, 0, 13),
#     'seizures': []},
#    {'name': 'chb07_03.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 1, 0, 21),
#     'end_time': datetime.datetime(2075, 3, 11, 5, 0, 21),
#     'seizures': []},
#    {'name': 'chb07_04.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 5, 0, 29),
#     'end_time': datetime.datetime(2075, 3, 11, 9, 0, 29),
#     'seizures': []},
#    {'name': 'chb07_05.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 9, 0, 36),
#     'end_time': datetime.datetime(2075, 3, 11, 13, 0, 36),
#     'seizures': []},
#    {'name': 'chb07_06.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 13, 0, 44),
#     'end_time': datetime.datetime(2075, 3, 11, 14, 22, 44),
#     'seizures': []},
# ...
#     'seizures': []},
#    {'name': 'chb21_13.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 5, 58, 6),
#     'end_time': datetime.datetime(2075, 3, 11, 6, 58, 6),
#     'seizures': []},
#    {'name': 'chb21_14.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 6, 58, 13),
#     'end_time': datetime.datetime(2075, 3, 11, 7, 58, 13),
#     'seizures': []},
#    {'name': 'chb21_15.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 7, 58, 20),
#     'end_time': datetime.datetime(2075, 3, 11, 8, 58, 20),
#     'seizures': []},
#    {'name': 'chb21_16.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 8, 58, 27),
#     'end_time': datetime.datetime(2075, 3, 11, 9, 58, 26),
#     'seizures': []},
#    {'name': 'chb21_17.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 9, 58, 59),
#     'end_time': datetime.datetime(2075, 3, 11, 10, 58, 59),
#     'seizures': []},
#    {'name': 'chb21_18.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 10, 59, 6),
#     'end_time': datetime.datetime(2075, 3, 11, 11, 59, 6),
#     'seizures': []},
#    {'name': 'chb21_19.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 11, 59, 13),
#     'end_time': datetime.datetime(2075, 3, 11, 12, 59, 13),
#     'seizures': [{'start_time': 1288, 'end_time': 1344}]},
#    {'name': 'chb21_20.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 12, 59, 20),
#     'end_time': datetime.datetime(2075, 3, 11, 13, 49, 10),
#     'seizures': [{'start_time': 2627, 'end_time': 2677}]},
#    {'name': 'chb21_21.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 15, 49, 35),
#     'end_time': datetime.datetime(2075, 3, 11, 16, 49, 35),
#     'seizures': [{'start_time': 2003, 'end_time': 2084}]},
#    {'name': 'chb21_22.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 16, 49, 42),
#     'end_time': datetime.datetime(2075, 3, 11, 17, 49, 42),
#     'seizures': [{'start_time': 2553, 'end_time': 2565}]},
#    {'name': 'chb21_23.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 18, 36, 1),
#     'end_time': datetime.datetime(2075, 3, 11, 19, 36, 1),
#     'seizures': []},
#    {'name': 'chb21_24.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 20, 36, 11),
#     'end_time': datetime.datetime(2075, 3, 11, 21, 36, 11),
#     'seizures': []},
#    {'name': 'chb21_25.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 22, 36, 25),
#     'end_time': datetime.datetime(2075, 3, 11, 23, 36, 25),
#     'seizures': []},
#    {'name': 'chb21_26.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 23, 36, 32),
#     'end_time': datetime.datetime(2075, 3, 12, 0, 36, 32),
#     'seizures': []},
#    {'name': 'chb21_27.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 0, 36, 39),
#     'end_time': datetime.datetime(2075, 3, 12, 1, 36, 39),
#     'seizures': []},
#    {'name': 'chb21_28.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 1, 36, 46),
#     'end_time': datetime.datetime(2075, 3, 12, 2, 36, 46),
#     'seizures': []},
#    {'name': 'chb21_29.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 8, 37, 34),
#     'end_time': datetime.datetime(2075, 3, 12, 9, 37, 34),
#     'seizures': []},
#    {'name': 'chb21_30.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 13, 38, 8),
#     'end_time': datetime.datetime(2075, 3, 12, 14, 38, 8),
#     'seizures': []},
#    {'name': 'chb21_31.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 22, 39, 10),
#     'end_time': datetime.datetime(2075, 3, 12, 23, 39, 10),
#     'seizures': []},
#    {'name': 'chb21_32.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 23, 39, 17),
#     'end_time': datetime.datetime(2075, 3, 13, 0, 39, 17),
#     'seizures': []},
#    {'name': 'chb21_33.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 13, 0, 39, 24),
#     'end_time': datetime.datetime(2075, 3, 13, 1, 39, 24),
#     'seizures': []}]},
#  {'patient_id': 'chb22',
#   'file_duration': 1,
#   'sampling_rate': 256,
#   'channels_list': [['FP1-F7',
#     'F7-T7',
#     'T7-P7',
#     'P7-O1',
#     '-',
#     'FP1-F3',
#     'F3-C3',
#     'C3-P3',
#     'P3-O1',
#     '-',
#     'FZ-CZ',
#     'CZ-PZ',
#     '-',
#     'FP2-F4',
#     'F4-C4',
#     'C4-P4',
#     'P4-O2',
#     '-',
#     'FP2-F8',
#     'F8-T8',
#     'T8-P8',
#     'P8-O2',
#     '-',
#     'P7-T7',
#     'T7-FT9',
#     'FT9-FT10',
#     'FT10-T8',
#     'T8-P8']],
#   'files': [{'name': 'chb22_01.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 22, 38, 9),
#     'end_time': datetime.datetime(2075, 3, 10, 23, 38, 9),
#     'seizures': []},
#    {'name': 'chb22_02.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 23, 38, 12),
#     'end_time': datetime.datetime(2075, 3, 11, 0, 38, 12),
#     'seizures': []},
#    {'name': 'chb22_03.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 0, 38, 18),
#     'end_time': datetime.datetime(2075, 3, 11, 1, 38, 18),
#     'seizures': []},
#    {'name': 'chb22_04.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 1, 38, 25),
#     'end_time': datetime.datetime(2075, 3, 11, 2, 38, 25),
#     'seizures': []},
#    {'name': 'chb22_05.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 2, 38, 32),
#     'end_time': datetime.datetime(2075, 3, 11, 3, 38, 32),
#     'seizures': []},
#    {'name': 'chb22_06.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 3, 38, 39),
#     'end_time': datetime.datetime(2075, 3, 11, 4, 38, 39),
#     'seizures': []},
#    {'name': 'chb22_07.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 4, 38, 45),
#     'end_time': datetime.datetime(2075, 3, 11, 5, 38, 45),
#     'seizures': []},
#    {'name': 'chb22_08.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 5, 38, 52),
#     'end_time': datetime.datetime(2075, 3, 11, 6, 38, 52),
#     'seizures': []},
#    {'name': 'chb22_09.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 6, 38, 59),
#     'end_time': datetime.datetime(2075, 3, 11, 7, 38, 59),
#     'seizures': []},
#    {'name': 'chb22_10.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 7, 39, 5),
#     'end_time': datetime.datetime(2075, 3, 11, 8, 39, 5),
#     'seizures': []},
#    {'name': 'chb22_11.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 8, 39, 12),
#     'end_time': datetime.datetime(2075, 3, 11, 9, 39, 23),
#     'seizures': []},
#    {'name': 'chb22_15.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 12, 44, 29),
#     'end_time': datetime.datetime(2075, 3, 11, 13, 44, 29),
#     'seizures': []},
#    {'name': 'chb22_16.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 13, 44, 36),
#     'end_time': datetime.datetime(2075, 3, 11, 14, 44, 36),
#     'seizures': []},
#    {'name': 'chb22_17.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 14, 44, 42),
#     'end_time': datetime.datetime(2075, 3, 11, 15, 44, 42),
#     'seizures': []},
#    {'name': 'chb22_18.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 15, 44, 49),
#     'end_time': datetime.datetime(2075, 3, 11, 16, 44, 49),
#     'seizures': []},
#    {'name': 'chb22_19.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 16, 44, 56),
#     'end_time': datetime.datetime(2075, 3, 11, 17, 44, 56),
#     'seizures': []},
#    {'name': 'chb22_20.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 17, 45, 3),
#     'end_time': datetime.datetime(2075, 3, 11, 18, 45, 3),
#     'seizures': [{'start_time': 3367, 'end_time': 3425}]},
#    {'name': 'chb22_21.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 18, 45, 10),
#     'end_time': datetime.datetime(2075, 3, 11, 19, 45, 10),
#     'seizures': []},
#    {'name': 'chb22_22.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 19, 45, 17),
#     'end_time': datetime.datetime(2075, 3, 11, 20, 45, 17),
#     'seizures': []},
#    {'name': 'chb22_23.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 20, 45, 24),
#     'end_time': datetime.datetime(2075, 3, 11, 21, 45, 24),
#     'seizures': []},
#    {'name': 'chb22_24.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 21, 45, 30),
#     'end_time': datetime.datetime(2075, 3, 11, 22, 45, 30),
#     'seizures': []},
#    {'name': 'chb22_25.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 22, 45, 37),
#     'end_time': datetime.datetime(2075, 3, 11, 23, 45, 37),
#     'seizures': [{'start_time': 3139, 'end_time': 3213}]},
#    {'name': 'chb22_26.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 23, 45, 44),
#     'end_time': datetime.datetime(2075, 3, 12, 0, 45, 44),
#     'seizures': []},
#    {'name': 'chb22_27.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 0, 45, 51),
#     'end_time': datetime.datetime(2075, 3, 12, 1, 45, 51),
#     'seizures': []},
#    {'name': 'chb22_28.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 1, 45, 58),
#     'end_time': datetime.datetime(2075, 3, 12, 2, 45, 58),
#     'seizures': []},
#    {'name': 'chb22_29.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 2, 46, 4),
#     'end_time': datetime.datetime(2075, 3, 12, 3, 46, 4),
#     'seizures': []},
#    {'name': 'chb22_30.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 3, 46, 11),
#     'end_time': datetime.datetime(2075, 3, 12, 4, 46, 11),
#     'seizures': []},
#    {'name': 'chb22_38.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 11, 47, 9),
#     'end_time': datetime.datetime(2075, 3, 12, 12, 47, 9),
#     'seizures': [{'start_time': 1263, 'end_time': 1335}]},
#    {'name': 'chb22_51.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 13, 1, 3, 25),
#     'end_time': datetime.datetime(2075, 3, 13, 2, 3, 25),
#     'seizures': []},
#    {'name': 'chb22_54.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 13, 4, 3, 46),
#     'end_time': datetime.datetime(2075, 3, 13, 5, 3, 46),
#     'seizures': []},
#    {'name': 'chb22_77.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 14, 1, 33, 40),
#     'end_time': datetime.datetime(2075, 3, 14, 2, 33, 40),
#     'seizures': []}]},
#  {'patient_id': 'chb23',
#   'file_duration': 4,
#   'sampling_rate': 256,
#   'channels_list': [['FP1-F7',
#     'F7-T7',
#     'T7-P7',
#     'P7-O1',
#     'FP1-F3',
#     'F3-C3',
#     'C3-P3',
#     'P3-O1',
#     'FP2-F4',
#     'F4-C4',
#     'C4-P4',
#     'P4-O2',
#     'FP2-F8',
#     'F8-T8',
#     'T8-P8',
#     'P8-O2',
#     'FZ-CZ',
#     'CZ-PZ',
#     'P7-T7',
#     'T7-FT9',
#     'FT9-FT10',
#     'FT10-T8',
#     'T8-P8']],
#   'files': [{'name': 'chb23_06.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 8, 57, 57),
#     'end_time': datetime.datetime(2075, 3, 10, 11, 2, 43),
#     'seizures': [{'start_time': 3962, 'end_time': 4075}]},
#    {'name': 'chb23_07.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 11, 3, 16),
#     'end_time': datetime.datetime(2075, 3, 10, 11, 45, 56),
#     'seizures': []},
#    {'name': 'chb23_08.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 11, 48, 5),
#     'end_time': datetime.datetime(2075, 3, 10, 14, 40, 27),
#     'seizures': [{'start_time': 325, 'end_time': 345},
#      {'start_time': 5104, 'end_time': 5151}]},
#    {'name': 'chb23_09.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 14, 40, 47),
#     'end_time': datetime.datetime(2075, 3, 10, 18, 41, 13),
#     'seizures': [{'start_time': 2589, 'end_time': 2660},
#      {'start_time': 6885, 'end_time': 6947},
#      {'start_time': 8505, 'end_time': 8532},
#      {'start_time': 9580, 'end_time': 9664}]},
#    {'name': 'chb23_10.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 10, 18, 41, 40),
#     'end_time': datetime.datetime(2075, 3, 10, 22, 41, 40),
#     'seizures': []},
#    {'name': 'chb23_16.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 13, 46, 32),
#     'end_time': datetime.datetime(2075, 3, 11, 17, 46, 32),
#     'seizures': []},
#    {'name': 'chb23_17.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 11, 17, 46, 42),
#     'end_time': datetime.datetime(2075, 3, 11, 21, 16, 29),
#     'seizures': []},
#    {'name': 'chb23_19.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 2, 28, 28),
#     'end_time': datetime.datetime(2075, 3, 12, 6, 28, 28),
#     'seizures': []},
#    {'name': 'chb23_20.edf',
#     'channels_set_idx': 0,
#     'start_time': datetime.datetime(2075, 3, 12, 6, 28, 36),
#     'end_time': datetime.datetime(2075, 3, 12, 7, 52, 5),
#     'seizures': []}]},
#  {'patient_id': 'chb24',
#   'file_duration': 1,
#   'sampling_rate': 256,
#   'channels_list': [['FP1-F7',
#     'F7-T7',
#     'T7-P7',
#     'P7-O1',
#     'FP1-F3',
#     'F3-C3',
#     'C3-P3',
#     'P3-O1',
#     'FP2-F4',
#     'F4-C4',
#     'C4-P4',
#     'P4-O2',
#     'FP2-F8',
#     'F8-T8',
#     'T8-P8',
#     'P8-O2',
#     'FZ-CZ',
#     'CZ-PZ',
#     'P7-T7',
#     'T7-FT9',
#     'FT9-FT10',
#     'FT10-T8',
#     'T8-P8']],
#   'files': [{'name': 'chb24_01.edf',
#     'channels_set_idx': 0,
#     'start_time': None,
#     'end_time': None,
#     'seizures': [{'start_time': 480, 'end_time': 505},
#      {'start_time': 2451, 'end_time': 2476}]},
#    {'name': 'chb24_03.edf',
#     'channels_set_idx': 0,
#     'start_time': None,
#     'end_time': None,
#     'seizures': [{'start_time': 231, 'end_time': 260},
#      {'start_time': 2883, 'end_time': 2908}]},
#    {'name': 'chb24_04.edf',
#     'channels_set_idx': 0,
#     'start_time': None,
#     'end_time': None,
#     'seizures': [{'start_time': 1088, 'end_time': 1120},
#      {'start_time': 1411, 'end_time': 1438},
#      {'start_time': 1745, 'end_time': 1764}]},
#    {'name': 'chb24_06.edf',
#     'channels_set_idx': 0,
#     'start_time': None,
#     'end_time': None,
#     'seizures': [{'start_time': 1229, 'end_time': 1253}]},
#    {'name': 'chb24_07.edf',
#     'channels_set_idx': 0,
#     'start_time': None,
#     'end_time': None,
#     'seizures': [{'start_time': 38, 'end_time': 60}]},
#    {'name': 'chb24_09.edf',
#     'channels_set_idx': 0,
#     'start_time': None,
#     'end_time': None,
#     'seizures': [{'start_time': 1745, 'end_time': 1764}]},
#    {'name': 'chb24_11.edf',
#     'channels_set_idx': 0,
#     'start_time': None,
#     'end_time': None,
#     'seizures': [{'start_time': 3527, 'end_time': 3597}]},
#    {'name': 'chb24_13.edf',
#     'channels_set_idx': 0,
#     'start_time': None,
#     'end_time': None,
#     'seizures': [{'start_time': 3288, 'end_time': 3304}]},
#    {'name': 'chb24_14.edf',
#     'channels_set_idx': 0,
#     'start_time': None,
#     'end_time': None,
#     'seizures': [{'start_time': 1939, 'end_time': 1966}]},
#    {'name': 'chb24_15.edf',
#     'channels_set_idx': 0,
#     'start_time': None,
#     'end_time': None,
#     'seizures': [{'start_time': 3552, 'end_time': 3569}]},
#    {'name': 'chb24_17.edf',
#     'channels_set_idx': 0,
#     'start_time': None,
#     'end_time': None,
#     'seizures': [{'start_time': 3515, 'end_time': 3581}]},
#    {'name': 'chb24_21.edf',
#     'channels_set_idx': 0,
#     'start_time': None,
#     'end_time': None,
#     'seizures': [{'start_time': 2804, 'end_time': 2872}]}]}]

# %% [markdown]
# Let check the result

# %%
from pprint import pprint

pprint(filtered_summary_info[0], width=80, indent=2)
# Out:
# { 'channels_list': [ [ 'FP1-F7',
#                        'F7-T7',
#                        'T7-P7',
#                        'P7-O1',
#                        'FP1-F3',
#                        'F3-C3',
#                        'C3-P3',
#                        'P3-O1',
#                        'FP2-F4',
#                        'F4-C4',
#                        'C4-P4',
#                        'P4-O2',
#                        'FP2-F8',
#                        'F8-T8',
#                        'T8-P8',
#                        'P8-O2',
#                        'FZ-CZ',
#                        'CZ-PZ',
#                        'P7-T7',
#                        'T7-FT9',
#                        'FT9-FT10',
#                        'FT10-T8',
#                        'T8-P8']],
#   'file_duration': 1,
#   'files': [ { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 10, 12, 42, 54),
#                'name': 'chb01_01.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 10, 11, 42, 54)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 10, 13, 42, 57),
#                'name': 'chb01_02.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 10, 12, 42, 57)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 10, 14, 43, 4),
#                'name': 'chb01_03.edf',
#                'seizures': [{'end_time': 3036, 'start_time': 2996}],
#                'start_time': datetime.datetime(2075, 3, 10, 13, 43, 4)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 10, 15, 43, 12),
#                'name': 'chb01_04.edf',
#                'seizures': [{'end_time': 1494, 'start_time': 1467}],
#                'start_time': datetime.datetime(2075, 3, 10, 14, 43, 12)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 10, 16, 43, 19),
#                'name': 'chb01_05.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 10, 15, 43, 19)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 10, 17, 43, 26),
#                'name': 'chb01_06.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 10, 16, 43, 26)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 10, 18, 43, 33),
#                'name': 'chb01_07.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 10, 17, 43, 33)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 10, 19, 43, 40),
#                'name': 'chb01_08.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 10, 18, 43, 40)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 10, 20, 43, 56),
#                'name': 'chb01_09.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 10, 19, 43, 56)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 10, 21, 44, 7),
#                'name': 'chb01_10.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 10, 20, 44, 7)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 10, 22, 44, 14),
#                'name': 'chb01_11.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 10, 21, 44, 14)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 10, 23, 44, 22),
#                'name': 'chb01_12.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 10, 22, 44, 22)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 0, 44, 29),
#                'name': 'chb01_13.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 10, 23, 44, 29)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 1, 44, 37),
#                'name': 'chb01_14.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 0, 44, 37)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 2, 44, 44),
#                'name': 'chb01_15.edf',
#                'seizures': [{'end_time': 1772, 'start_time': 1732}],
#                'start_time': datetime.datetime(2075, 3, 11, 1, 44, 44)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 3, 44, 51),
#                'name': 'chb01_16.edf',
#                'seizures': [{'end_time': 1066, 'start_time': 1015}],
#                'start_time': datetime.datetime(2075, 3, 11, 2, 44, 51)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 4, 44, 59),
#                'name': 'chb01_17.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 3, 44, 59)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 5, 45, 6),
#                'name': 'chb01_18.edf',
#                'seizures': [{'end_time': 1810, 'start_time': 1720}],
#                'start_time': datetime.datetime(2075, 3, 11, 4, 45, 6)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 6, 45, 13),
#                'name': 'chb01_19.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 5, 45, 13)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 7, 29, 43),
#                'name': 'chb01_20.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 6, 45, 20)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 8, 33, 46),
#                'name': 'chb01_21.edf',
#                'seizures': [{'end_time': 420, 'start_time': 327}],
#                'start_time': datetime.datetime(2075, 3, 11, 7, 33, 46)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 9, 33, 49),
#                'name': 'chb01_22.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 8, 33, 49)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 10, 33, 58),
#                'name': 'chb01_23.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 9, 33, 58)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 11, 34, 6),
#                'name': 'chb01_24.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 10, 34, 6)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 12, 34, 14),
#                'name': 'chb01_25.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 11, 34, 14)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 13, 13, 7),
#                'name': 'chb01_26.edf',
#                'seizures': [{'end_time': 1963, 'start_time': 1862}],
#                'start_time': datetime.datetime(2075, 3, 11, 12, 34, 22)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 13, 23, 21),
#                'name': 'chb01_27.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 13, 13, 21)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 14, 24, 8),
#                'name': 'chb01_29.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 13, 24, 8)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 15, 24, 15),
#                'name': 'chb01_30.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 14, 24, 15)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 16, 24, 24),
#                'name': 'chb01_31.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 15, 24, 24)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 17, 24, 32),
#                'name': 'chb01_32.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 16, 24, 32)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 18, 24, 39),
#                'name': 'chb01_33.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 17, 24, 39)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 19, 24, 46),
#                'name': 'chb01_34.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 18, 24, 46)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 11, 23, 14, 43),
#                'name': 'chb01_36.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 22, 14, 43)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 12, 0, 14, 46),
#                'name': 'chb01_37.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 11, 23, 14, 46)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 12, 1, 14, 53),
#                'name': 'chb01_38.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 12, 0, 14, 53)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 12, 2, 15, 1),
#                'name': 'chb01_39.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 12, 1, 15, 1)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 12, 3, 15, 8),
#                'name': 'chb01_40.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 12, 2, 15, 8)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 12, 4, 15, 15),
#                'name': 'chb01_41.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 12, 3, 15, 15)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 12, 5, 15, 22),
#                'name': 'chb01_42.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 12, 4, 15, 22)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 12, 6, 15, 29),
#                'name': 'chb01_43.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 12, 5, 15, 29)},
#              { 'channels_set_idx': 0,
#                'end_time': datetime.datetime(2075, 3, 12, 9, 15, 51),
#                'name': 'chb01_46.edf',
#                'seizures': [],
#                'start_time': datetime.datetime(2075, 3, 12, 8, 15, 51)}],
#   'patient_id': 'chb01',
#   'sampling_rate': 256}

# %%
filtered_summary_info[3]['files'][8:]
# Out:
# [{'name': 'chb04_09.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 11, 22, 53, 33),
#   'end_time': datetime.datetime(2075, 3, 12, 2, 53, 33),
#   'seizures': []},
#  {'name': 'chb04_10.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 12, 2, 53, 41),
#   'end_time': datetime.datetime(2075, 3, 12, 6, 53, 41),
#   'seizures': []},
#  {'name': 'chb04_11.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 12, 6, 53, 48),
#   'end_time': datetime.datetime(2075, 3, 12, 8, 14, 20),
#   'seizures': []},
#  {'name': 'chb04_12.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 12, 8, 16, 27),
#   'end_time': datetime.datetime(2075, 3, 12, 12, 16, 47),
#   'seizures': []},
#  {'name': 'chb04_13.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 12, 12, 17, 31),
#   'end_time': datetime.datetime(2075, 3, 12, 16, 17, 29),
#   'seizures': []},
#  {'name': 'chb04_14.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 12, 16, 18, 2),
#   'end_time': datetime.datetime(2075, 3, 12, 20, 18, 20),
#   'seizures': []},
#  {'name': 'chb04_15.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 12, 20, 19, 43),
#   'end_time': datetime.datetime(2075, 3, 13, 0, 19, 43),
#   'seizures': []},
#  {'name': 'chb04_16.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 13, 0, 19, 51),
#   'end_time': datetime.datetime(2075, 3, 13, 4, 19, 51),
#   'seizures': []},
#  {'name': 'chb04_17.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 13, 4, 19, 59),
#   'end_time': datetime.datetime(2075, 3, 13, 8, 8, 51),
#   'seizures': []},
#  {'name': 'chb04_18.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 13, 8, 11, 11),
#   'end_time': datetime.datetime(2075, 3, 13, 12, 11, 36),
#   'seizures': []},
#  {'name': 'chb04_19.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 13, 12, 41, 24),
#   'end_time': datetime.datetime(2075, 3, 13, 16, 41, 24),
#   'seizures': []},
#  {'name': 'chb04_21.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 13, 20, 41, 40),
#   'end_time': datetime.datetime(2075, 3, 14, 0, 41, 40),
#   'seizures': []},
#  {'name': 'chb04_22.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 14, 0, 41, 48),
#   'end_time': datetime.datetime(2075, 3, 14, 4, 41, 48),
#   'seizures': []},
#  {'name': 'chb04_23.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 14, 4, 41, 55),
#   'end_time': datetime.datetime(2075, 3, 14, 7, 39, 59),
#   'seizures': []},
#  {'name': 'chb04_24.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 14, 7, 41, 42),
#   'end_time': datetime.datetime(2075, 3, 14, 11, 41, 48),
#   'seizures': []},
#  {'name': 'chb04_25.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 14, 11, 46, 2),
#   'end_time': datetime.datetime(2075, 3, 14, 15, 46, 2),
#   'seizures': []},
#  {'name': 'chb04_26.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 14, 15, 46, 10),
#   'end_time': datetime.datetime(2075, 3, 14, 19, 46, 10),
#   'seizures': []},
#  {'name': 'chb04_27.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 14, 19, 46, 17),
#   'end_time': datetime.datetime(2075, 3, 14, 23, 46, 44),
#   'seizures': []},
#  {'name': 'chb04_28.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 15, 0, 4, 47),
#   'end_time': datetime.datetime(2075, 3, 15, 4, 5, 10),
#   'seizures': [{'start_time': 1679, 'end_time': 1781},
#    {'start_time': 3782, 'end_time': 3898}]},
#  {'name': 'chb04_29.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 15, 4, 6, 56),
#   'end_time': datetime.datetime(2075, 3, 15, 8, 6, 59),
#   'seizures': []},
#  {'name': 'chb04_30.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 15, 8, 7, 45),
#   'end_time': datetime.datetime(2075, 3, 15, 12, 7, 45),
#   'seizures': []},
#  {'name': 'chb04_31.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 15, 12, 7, 53),
#   'end_time': datetime.datetime(2075, 3, 15, 16, 7, 53),
#   'seizures': []},
#  {'name': 'chb04_32.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 15, 16, 8),
#   'end_time': datetime.datetime(2075, 3, 15, 20, 8),
#   'seizures': []},
#  {'name': 'chb04_33.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 15, 20, 8, 8),
#   'end_time': datetime.datetime(2075, 3, 16, 0, 8, 8),
#   'seizures': []},
#  {'name': 'chb04_34.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 16, 0, 8, 16),
#   'end_time': datetime.datetime(2075, 3, 16, 4, 8, 16),
#   'seizures': []},
#  {'name': 'chb04_35.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 16, 4, 8, 24),
#   'end_time': datetime.datetime(2075, 3, 16, 8, 8, 24),
#   'seizures': []},
#  {'name': 'chb04_36.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 16, 8, 8, 31),
#   'end_time': datetime.datetime(2075, 3, 16, 12, 8, 31),
#   'seizures': []},
#  {'name': 'chb04_37.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 16, 12, 8, 39),
#   'end_time': datetime.datetime(2075, 3, 16, 13, 42, 12),
#   'seizures': []},
#  {'name': 'chb04_38.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 16, 14, 37, 59),
#   'end_time': datetime.datetime(2075, 3, 16, 18, 37, 59),
#   'seizures': []},
#  {'name': 'chb04_39.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 16, 18, 38, 2),
#   'end_time': datetime.datetime(2075, 3, 16, 22, 38, 2),
#   'seizures': []},
#  {'name': 'chb04_40.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 16, 22, 38, 10),
#   'end_time': datetime.datetime(2075, 3, 17, 2, 38, 10),
#   'seizures': []},
#  {'name': 'chb04_41.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 17, 2, 38, 18),
#   'end_time': datetime.datetime(2075, 3, 17, 6, 38, 18),
#   'seizures': []},
#  {'name': 'chb04_42.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 17, 6, 38, 25),
#   'end_time': datetime.datetime(2075, 3, 17, 8, 15, 28),
#   'seizures': []},
#  {'name': 'chb04_43.edf',
#   'channels_set_idx': 1,
#   'start_time': datetime.datetime(2075, 3, 17, 8, 17, 50),
#   'end_time': datetime.datetime(2075, 3, 17, 12, 17, 50),
#   'seizures': []}]

# %% [markdown]
# # Total Seizures in dataset

# %%
import pandas as pd

seizure_count = {}

for i, patient_info in enumerate(filtered_summary_info):
    patient_id = f"chb{(i + 1):02}"
    for file in patient_info['files']:
        for seizure in file["seizures"]:
            seizure_count[patient_id] = seizure_count.get(patient_id, 0) + 1

sezure_count = pd.DataFrame.from_dict(seizure_count, orient='index', columns=['seizure_count'])

display(sezure_count)
display(sezure_count.sum())
# Out:
#        seizure_count
# chb01              7
# chb02              3
# chb03              7
# chb04              4
# chb05              5
# chb06             10
# chb07              3
# chb08              5
# chb09              4
# chb10              7
# chb11              3
# chb12             27
# chb13             10
# chb14              8
# chb15             20
# chb16              8
# chb17              3
# chb18              6
# chb19              3
# chb20              8
# chb21              4
# chb22              3
# chb23              7
# chb24             16
# seizure_count    181
# dtype: int64

# %%
COMMON_CHANNELS = [
    "C3-P3",
    "C4-P4",
    "CZ-PZ",
    "F3-C3",
    "F4-C4",
    "F7-T7",
    "F8-T8",
    "FP1-F3",
    "FP1-F7",
    "FP2-F4",
    "FP2-F8",
    "FT10-T8",
    "FT9-FT10",
    "FZ-CZ",
    "P3-O1",
    "P4-O2",
    "P7-O1",
    "P7-T7",
    "P8-O2",
    "T7-FT9",
    "T7-P7",
    "T8-P8",
]

# %% [markdown]
# ## Exclude abnormal data
# We have checking each records and found that most of the record using this `"C3-P3","C4-P4","CZ-PZ","F3-C3","F4-C4","F7-T7","F8-T8","FP1-F3","FP1-F7","FP2-F4","FP2-F8","FT10-T8","FT9-FT10","FZ-CZ","P3-O1","P4-O2","P7-O1","P7-T7","P8-O2","T7-FT9","T7-P7","T8-P8"` excepts the `chb12_27.edf`, `chb12_28.edf` and `chb12_29.edf` that didn't use this channels configuration. But we already filter out the files those are not use the common channels already.

# %% [markdown]
# But for making sure, we will check which files those contain seizure don't contain all channels in common channels

# %%
from utils.constant import COMMON_CHANNELS

channels_set = set(COMMON_CHANNELS)

for i, patient_info in enumerate(filtered_summary_info):
    for file in patient_info['files']:
        if file["name"] in ["chb12_27.edf", "chb12_28.edf", "chb12_29.edf"]:
            continue
        
        current_file_channels = set(patient_info["channels_list"][file["channels_set_idx"]])
        missing_channels = channels_set - current_file_channels
        
        if (len(file["seizures"]) > 0) and len(missing_channels) > 0:
            print(f"Missing channels in {file['name']}: {missing_channels}, Seizure Count: {len(file['seizures'])}")

# %% [markdown]
# ## Checking the total usable ictal class

# %%
from utils import dataset


ictal_list = dataset.list_ictal(filtered_summary_info)
ictal_df = pd.DataFrame(ictal_list)
ictal_df
# Out:
#              file  start_time  end_time  total_time  total_windows
# 0    chb01_03.edf        2996      3036          40              9
# 1    chb01_04.edf        1467      1494          27              5
# 2    chb01_15.edf        1732      1772          40              9
# 3    chb01_16.edf        1015      1066          51             11
# 4    chb01_18.edf        1720      1810          90             21
# ..            ...         ...       ...         ...            ...
# 176  chb24_13.edf        3288      3304          16              3
# 177  chb24_14.edf        1939      1966          27              5
# 178  chb24_15.edf        3552      3569          17              3
# 179  chb24_17.edf        3515      3581          66             15
# 180  chb24_21.edf        2804      2872          68             16
#
# [181 rows x 5 columns]

# %% [markdown]
# Now we can check how many windows we got for ictal class

# %%
ictal_df.sum()
# Out:
# file             chb01_03.edfchb01_04.edfchb01_15.edfchb01_16.e...
# start_time                                                  473011
# end_time                                                    484026
# total_time                                                   11015
# total_windows                                                 2509
# dtype: object

# %% [markdown]
# ## Checking the total usable interictal class
#
# For the interictal, it is more tricky to choose as we need to consider the ictal class. If we choosing it too close to the ictal class it might capture the pre-ictal phrase. To be able to safely get the interictal class we need to get the item that in range before or after the ictal several hours.

# %%
interictal_list = dataset.list_interictal(filtered_summary_info, ictal_list)
interictal_df = pd.DataFrame(interictal_list)
interictal_df
# Out:
#              file  total_time  total_windows
# 0    chb01_09.edf        3600            899
# 1    chb01_10.edf        3600            899
# 2    chb01_32.edf        3600            899
# 3    chb01_33.edf        3600            899
# 4    chb01_34.edf        3600            899
# ..            ...         ...            ...
# 272  chb22_15.edf        3600            899
# 273  chb23_16.edf       14400           3599
# 274  chb23_17.edf       14400           3599
# 275  chb23_19.edf       14400           3599
# 276  chb23_20.edf       14400           3599
#
# [277 rows x 3 columns]

# %%
interictal_df.sum()
# Out:
# file             chb01_09.edfchb01_10.edfchb01_32.edfchb01_33.e...
# total_time                                                 1742400
# total_windows                                               435323
# dtype: object

# %% [markdown]
# ## Prepare dataset
#
# From info above we can contruct the dataset that contain ictal and interictal class that both class has 2509 samples. And since the interictal class is for much more that the ictal class we can randomly select it to match the ictal class. Since we need 2509 windows we can roughly select 9 windows from each files and randomly discard the remainder.

# %%
dataset.save_ictal("./CHB-MIT", ictal_list)
# Out:
# Processing chb01_03.edf
# Processing chb01_04.edf
# Processing chb01_15.edf
# Processing chb01_16.edf
# Processing chb01_18.edf
# Processing chb01_21.edf
# Processing chb01_26.edf
# Processing chb02_16.edf
# Processing chb02_16+.edf
# Processing chb02_19.edf
# Processing chb03_01.edf
# Processing chb03_02.edf
# Processing chb03_03.edf
# Processing chb03_04.edf
# Processing chb03_34.edf
# Processing chb03_35.edf
# Processing chb03_36.edf
# Processing chb04_05.edf
# Processing chb04_08.edf
# Processing chb04_28.edf
# Processing chb04_28.edf
# Processing chb05_06.edf
# Processing chb05_13.edf
# Processing chb05_16.edf
# Processing chb05_17.edf
# Processing chb05_22.edf
# Processing chb06_01.edf
# Processing chb06_01.edf
# Processing chb06_01.edf
# Processing chb06_04.edf
# Processing chb06_04.edf
# Processing chb06_09.edf
# Processing chb06_10.edf
# Processing chb06_13.edf
# Processing chb06_18.edf
# Processing chb06_24.edf
# Processing chb07_12.edf
# Processing chb07_13.edf
# Processing chb07_19.edf
# Processing chb08_02.edf
# Processing chb08_05.edf
# Processing chb08_11.edf
# Processing chb08_13.edf
# Processing chb08_21.edf
# Processing chb09_06.edf
# Processing chb09_08.edf
# Processing chb09_08.edf
# Processing chb09_19.edf
# Processing chb10_12.edf
# Processing chb10_20.edf
# Processing chb10_27.edf
# Processing chb10_30.edf
# Processing chb10_31.edf
# Processing chb10_38.edf
# Processing chb10_89.edf
# Processing chb11_82.edf
# Processing chb11_92.edf
# Processing chb11_99.edf
# Processing chb12_06.edf
# Processing chb12_06.edf
# Processing chb12_08.edf
# Processing chb12_08.edf
# Processing chb12_08.edf
# Processing chb12_08.edf
# Processing chb12_09.edf
# Processing chb12_09.edf
# Processing chb12_10.edf
# Processing chb12_10.edf
# Processing chb12_11.edf
# Processing chb12_23.edf
# Processing chb12_23.edf
# Processing chb12_23.edf
# Processing chb12_33.edf
# Processing chb12_33.edf
# Processing chb12_36.edf
# Processing chb12_38.edf
# Processing chb12_38.edf
# Processing chb12_38.edf
# Processing chb12_38.edf
# Processing chb12_38.edf
# Processing chb12_42.edf
# Processing chb12_42.edf
# Processing chb12_42.edf
# Processing chb12_42.edf
# Processing chb12_42.edf
# Processing chb13_19.edf
# Processing chb13_21.edf
# Processing chb13_55.edf
# Processing chb13_55.edf
# Processing chb13_58.edf
# Processing chb13_59.edf
# Processing chb13_60.edf
# Processing chb13_62.edf
# Processing chb13_62.edf
# Processing chb13_62.edf
# Processing chb14_03.edf
# Processing chb14_04.edf
# Processing chb14_04.edf
# Processing chb14_06.edf
# Processing chb14_11.edf
# Processing chb14_17.edf
# Processing chb14_18.edf
# Processing chb14_27.edf
# Processing chb15_06.edf
# Processing chb15_10.edf
# Processing chb15_15.edf
# Processing chb15_17.edf
# Processing chb15_20.edf
# Processing chb15_22.edf
# Processing chb15_28.edf
# Processing chb15_31.edf
# Processing chb15_40.edf
# Processing chb15_40.edf
# Processing chb15_40.edf
# Processing chb15_46.edf
# Processing chb15_49.edf
# Processing chb15_52.edf
# Processing chb15_54.edf
# Processing chb15_54.edf
# Processing chb15_54.edf
# Processing chb15_54.edf
# Processing chb15_54.edf
# Processing chb15_62.edf
# Processing chb16_10.edf
# Processing chb16_11.edf
# Processing chb16_14.edf
# Processing chb16_16.edf
# Processing chb16_17.edf
# Processing chb16_17.edf
# Processing chb16_17.edf
# Processing chb16_17.edf
# Processing chb17a_03.edf
# Processing chb17a_04.edf
# Processing chb17b_63.edf
# Processing chb18_29.edf
# Processing chb18_30.edf
# Processing chb18_31.edf
# Processing chb18_32.edf
# Processing chb18_35.edf
# Processing chb18_36.edf
# Processing chb19_28.edf
# Processing chb19_29.edf
# Processing chb19_30.edf
# Processing chb20_12.edf
# Processing chb20_13.edf
# Processing chb20_13.edf
# Processing chb20_14.edf
# Processing chb20_15.edf
# Processing chb20_15.edf
# Processing chb20_16.edf
# Processing chb20_68.edf
# Processing chb21_19.edf
# Processing chb21_20.edf
# Processing chb21_21.edf
# Processing chb21_22.edf
# Processing chb22_20.edf
# Processing chb22_25.edf
# Processing chb22_38.edf
# Processing chb23_06.edf
# Processing chb23_08.edf
# Processing chb23_08.edf
# Processing chb23_09.edf
# Processing chb23_09.edf
# Processing chb23_09.edf
# Processing chb23_09.edf
# Processing chb24_01.edf
# Processing chb24_01.edf
# Processing chb24_03.edf
# Processing chb24_03.edf
# Processing chb24_04.edf
# Processing chb24_04.edf
# Processing chb24_04.edf
# Processing chb24_06.edf
# Processing chb24_07.edf
# Processing chb24_09.edf
# Processing chb24_11.edf
# Processing chb24_13.edf
# Processing chb24_14.edf
# Processing chb24_15.edf
# Processing chb24_17.edf
# Processing chb24_21.edf

# %%
dataset.save_interictal("./CHB-MIT", interictal_list)
# Out:
# Processing chb01_09.edf
# Processing chb01_10.edf
# Processing chb01_32.edf
# Processing chb01_33.edf
# Processing chb01_34.edf
# Processing chb01_36.edf
# Processing chb01_37.edf
# Processing chb01_38.edf
# Processing chb01_39.edf
# Processing chb01_40.edf
# Processing chb01_41.edf
# Processing chb01_42.edf
# Processing chb01_43.edf
# Processing chb01_46.edf
# Processing chb02_01.edf
# Processing chb02_02.edf
# Processing chb02_03.edf
# Processing chb02_04.edf
# Processing chb02_05.edf
# Processing chb02_06.edf
# Processing chb02_07.edf
# Processing chb02_08.edf
# Processing chb02_09.edf
# Processing chb02_10.edf
# Processing chb02_11.edf
# Processing chb02_24.edf
# Processing chb02_25.edf
# Processing chb02_26.edf
# Processing chb02_27.edf
# Processing chb02_28.edf
# Processing chb02_29.edf
# Processing chb02_30.edf
# Processing chb02_31.edf
# Processing chb02_32.edf
# Processing chb02_33.edf
# Processing chb02_34.edf
# Processing chb02_35.edf
# Processing chb03_09.edf
# Processing chb03_10.edf
# Processing chb03_11.edf
# Processing chb03_12.edf
# Processing chb03_13.edf
# Processing chb03_14.edf
# Processing chb03_15.edf
# Processing chb03_16.edf
# Processing chb03_17.edf
# Processing chb03_18.edf
# Processing chb03_19.edf
# Processing chb03_20.edf
# Processing chb03_21.edf
# Processing chb03_22.edf
# Processing chb03_23.edf
# Processing chb03_24.edf
# Processing chb03_25.edf
# Processing chb03_26.edf
# Processing chb03_27.edf
# Processing chb03_28.edf
# Processing chb03_29.edf
# Processing chb04_01.edf
# Processing chb04_02.edf
# Processing chb04_03.edf
# Processing chb04_10.edf
# Processing chb04_11.edf
# Processing chb04_12.edf
# Processing chb04_13.edf
# Processing chb04_14.edf
# Processing chb04_15.edf
# Processing chb04_16.edf
# Processing chb04_17.edf
# Processing chb04_18.edf
# Processing chb04_19.edf
# Processing chb04_21.edf
# Processing chb04_22.edf
# Processing chb04_23.edf
# Processing chb04_24.edf
# Processing chb04_25.edf
# Processing chb04_26.edf
# Processing chb04_30.edf
# Processing chb04_31.edf
# Processing chb04_32.edf
# Processing chb04_33.edf
# Processing chb04_34.edf
# Processing chb04_35.edf
# Processing chb04_36.edf
# Processing chb04_37.edf
# Processing chb04_38.edf
# Processing chb04_39.edf
# Processing chb04_40.edf
# Processing chb04_41.edf
# Processing chb04_42.edf
# Processing chb04_43.edf
# Processing chb05_01.edf
# Processing chb05_27.edf
# Processing chb05_28.edf
# Processing chb05_29.edf
# Processing chb05_30.edf
# Processing chb05_31.edf
# Processing chb05_32.edf
# Processing chb05_33.edf
# Processing chb05_34.edf
# Processing chb05_35.edf
# Processing chb05_36.edf
# Processing chb05_37.edf
# Processing chb05_38.edf
# Processing chb05_39.edf
# Processing chb06_06.edf
# Processing chb06_07.edf
# Processing chb06_15.edf
# Processing chb06_16.edf
# Processing chb07_01.edf
# Processing chb07_02.edf
# Processing chb07_03.edf
# Processing chb07_04.edf
# Processing chb07_05.edf
# Processing chb07_06.edf
# Processing chb07_07.edf
# Processing chb07_08.edf
# Processing chb07_09.edf
# Processing chb07_10.edf
# Processing chb07_15.edf
# Processing chb07_16.edf
# Processing chb07_17.edf
# Processing chb09_01.edf
# Processing chb09_02.edf
# Processing chb09_03.edf
# Processing chb09_04.edf
# Processing chb09_10.edf
# Processing chb09_11.edf
# Processing chb09_12.edf
# Processing chb09_13.edf
# Processing chb09_14.edf
# Processing chb09_15.edf
# Processing chb09_16.edf
# Processing chb09_17.edf
# Processing chb10_01.edf
# Processing chb10_02.edf
# Processing chb10_03.edf
# Processing chb10_04.edf
# Processing chb10_05.edf
# Processing chb10_06.edf
# Processing chb10_15.edf
# Processing chb10_16.edf
# Processing chb10_17.edf
# Processing chb11_01.edf
# Processing chb11_02.edf
# Processing chb11_03.edf
# Processing chb11_04.edf
# Processing chb11_05.edf
# Processing chb11_06.edf
# Processing chb11_07.edf
# Processing chb11_08.edf
# Processing chb11_09.edf
# Processing chb11_10.edf
# Processing chb11_11.edf
# Processing chb11_12.edf
# Processing chb11_13.edf
# Processing chb11_14.edf
# Processing chb11_15.edf
# Processing chb11_16.edf
# Processing chb11_17.edf
# Processing chb11_18.edf
# Processing chb11_19.edf
# Processing chb11_24.edf
# Processing chb11_25.edf
# Processing chb11_26.edf
# Processing chb11_27.edf
# Processing chb11_53.edf
# Processing chb11_54.edf
# Processing chb11_55.edf
# Processing chb11_56.edf
# Processing chb11_58.edf
# Processing chb14_39.edf
# Processing chb14_42.edf
# Processing chb16_01.edf
# Processing chb16_02.edf
# Processing chb16_03.edf
# Processing chb16_04.edf
# Processing chb16_05.edf
# Processing chb17c_03.edf
# Processing chb17c_04.edf
# Processing chb17c_05.edf
# Processing chb17c_06.edf
# Processing chb17c_07.edf
# Processing chb17c_08.edf
# Processing chb18_02.edf
# Processing chb18_03.edf
# Processing chb18_04.edf
# Processing chb18_05.edf
# Processing chb18_06.edf
# Processing chb18_07.edf
# Processing chb18_08.edf
# Processing chb18_09.edf
# Processing chb18_10.edf
# Processing chb18_11.edf
# Processing chb18_12.edf
# Processing chb18_13.edf
# Processing chb18_14.edf
# Processing chb18_15.edf
# Processing chb18_16.edf
# Processing chb18_17.edf
# Processing chb18_18.edf
# Processing chb18_19.edf
# Processing chb18_20.edf
# Processing chb18_21.edf
# Processing chb18_22.edf
# Processing chb18_23.edf
# Processing chb18_24.edf
# Processing chb19_02.edf
# Processing chb19_03.edf
# Processing chb19_04.edf
# Processing chb19_05.edf
# Processing chb19_06.edf
# Processing chb19_07.edf
# Processing chb19_08.edf
# Processing chb19_09.edf
# Processing chb19_10.edf
# Processing chb19_11.edf
# Processing chb19_12.edf
# Processing chb19_13.edf
# Processing chb19_14.edf
# Processing chb19_15.edf
# Processing chb19_16.edf
# Processing chb19_17.edf
# Processing chb19_18.edf
# Processing chb19_19.edf
# Processing chb19_20.edf
# Processing chb19_21.edf
# Processing chb19_22.edf
# Processing chb19_23.edf
# Processing chb20_01.edf
# Processing chb20_02.edf
# Processing chb20_03.edf
# Processing chb20_04.edf
# Processing chb20_05.edf
# Processing chb20_25.edf
# Processing chb20_26.edf
# Processing chb20_27.edf
# Processing chb20_28.edf
# Processing chb20_29.edf
# Processing chb20_30.edf
# Processing chb21_01.edf
# Processing chb21_02.edf
# Processing chb21_03.edf
# Processing chb21_04.edf
# Processing chb21_05.edf
# Processing chb21_06.edf
# Processing chb21_07.edf
# Processing chb21_08.edf
# Processing chb21_09.edf
# Processing chb21_10.edf
# Processing chb21_11.edf
# Processing chb21_12.edf
# Processing chb21_13.edf
# Processing chb21_14.edf
# Processing chb21_27.edf
# Processing chb21_28.edf
# Processing chb21_29.edf
# Processing chb21_30.edf
# Processing chb21_31.edf
# Processing chb21_32.edf
# Processing chb21_33.edf
# Processing chb22_01.edf
# Processing chb22_02.edf
# Processing chb22_03.edf
# Processing chb22_04.edf
# Processing chb22_05.edf
# Processing chb22_06.edf
# Processing chb22_07.edf
# Processing chb22_08.edf
# Processing chb22_09.edf
# Processing chb22_10.edf
# Processing chb22_11.edf
# Processing chb22_15.edf
# Processing chb23_16.edf
# Processing chb23_17.edf
# Processing chb23_19.edf
# Processing chb23_20.edf
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 dataset.save_interictal("./CHB-MIT", interictal_list)
#
# File d:\KMUTT_Learnfile\2024-2\Project\utils\dataset.py:247, in save_interictal(dataset_path, interictal_list, window_size, random_seed, sample_size)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File numpy\\random\\mtrand.pyx:1020, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'
